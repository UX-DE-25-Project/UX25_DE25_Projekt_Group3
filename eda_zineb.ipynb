# %% [markdown]
# # EDA
# - explore the data
# - analys the data

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("ETL_Pipline/right_home_cleaned.csv")
df.head()
# Out:
#    id       typ upplåtelseform    pris  avgift  rum  boyta  kvadratmeterpris  \
# 0   1  lägenhet           köpa  620826    6808    5    135              4598
# 1   2       hus           köpa  691557    2078    4    100              6915
# 2   3       hus           köpa  192646    2399    1     28              6880
# 3   4       hus           hyra   19804       0    6    150                 0
# 4   5  lägenhet           hyra    5147       0    2     42                 0
#
#         område      stad             adress       lat       lon  tillgänglig  \
# 0    Rosengård     Malmö      Parkvägen 103  55.58769  13.03032        False
# 1      Majorna  Göteborg      Kyrkogatan 91  57.69776  11.92771         True
# 2  Linnéstaden  Göteborg      Hornsgatan 76  57.70313  11.95268         True
# 3       Hyllie     Malmö  Drottninggatan 72  55.57193  12.96539        False
# 4  Linnéstaden  Göteborg      Kyrkogatan 79  57.69152  11.96112         True
#
#    created_at valuta boyta_enhet  pris_per_kvm
# 0  2025-08-19    SEK          m²        4599.0
# 1  2026-02-02    SEK          m²        6916.0
# 2  2025-12-19    SEK          m²        6880.0
# 3  2025-10-22    SEK          m²         132.0
# 4  2026-04-08    SEK          m²         123.0

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                1000 non-null   int64
#  1   typ               1000 non-null   object
#  2   upplåtelseform    1000 non-null   object
#  3   pris              1000 non-null   int64
#  4   avgift            1000 non-null   int64
#  5   rum               1000 non-null   int64
#  6   boyta             1000 non-null   int64
#  7   kvadratmeterpris  1000 non-null   int64
#  8   område            1000 non-null   object
#  9   stad              1000 non-null   object
#  10  adress            1000 non-null   object
#  11  lat               1000 non-null   float64
#  12  lon               1000 non-null   float64
#  13  tillgänglig       1000 non-null   bool
#  14  created_at        1000 non-null   object
#  15  valuta            1000 non-null   object
#  16  boyta_enhet       1000 non-null   object
#  17  pris_per_kvm      1000 non-null   float64
# dtypes: bool(1), float64(3), int64(6), object(8)
# memory usage: 133.9+ KB
# None

# %%
print(df.describe())
# Out:
#                 id          pris       avgift          rum        boyta  \
# count  1000.000000  1.000000e+03   1000.00000  1000.000000  1000.000000
# mean    500.500000  3.093836e+05   1723.51800     3.613000    82.629000
# std     288.819436  4.061970e+05   2333.17113     1.695909    41.035342
# min       1.000000  2.238000e+03      0.00000     1.000000    18.000000
# 25%     250.750000  1.171500e+04      0.00000     2.000000    50.000000
# 50%     500.500000  2.651950e+04      0.00000     4.000000    80.000000
# 75%     750.250000  5.343608e+05   2598.75000     5.000000   112.000000
# max    1000.000000  1.894463e+06  12462.00000     6.000000   168.000000
#
#        kvadratmeterpris          lat          lon  pris_per_kvm
# count       1000.000000  1000.000000  1000.000000   1000.000000
# mean        3649.670000    57.471431    14.248523   3725.919000
# std         4155.660027     1.541621     2.631893   4089.263604
# min            0.000000    55.552160    11.890450    120.000000
# 25%            0.000000    55.602735    11.966845    147.750000
# 50%            0.000000    57.704440    12.974570    179.000000
# 75%         6782.000000    59.323175    18.035293   6782.250000
# max        13260.000000    59.352970    18.089760  13261.000000

# %%
print(df.shape)
print(df.dtypes)
print(df.isnull().sum())
# Out:
# (1000, 18)
# id                    int64
# typ                  object
# upplåtelseform       object
# pris                  int64
# avgift                int64
# rum                   int64
# boyta                 int64
# kvadratmeterpris      int64
# område               object
# stad                 object
# adress               object
# lat                 float64
# lon                 float64
# tillgänglig            bool
# created_at           object
# valuta               object
# boyta_enhet          object
# pris_per_kvm        float64
# dtype: object
# id                  0
# typ                 0
# upplåtelseform      0
# pris                0
# avgift              0
# rum                 0
# boyta               0
# kvadratmeterpris    0
# område              0
# stad                0
# adress              0
# lat                 0
# lon                 0
# tillgänglig         0
# created_at          0
# valuta              0
# boyta_enhet         0
# pris_per_kvm        0
# dtype: int64

# %%
# Visa snittpris per upplåtelseform
df.groupby("upplåtelseform")["pris"].describe()
# Out:
#                 count           mean            std      min        25%  \
# upplåtelseform
# hyra            508.0   12357.714567    6439.534094   2238.0    7077.75
# köpa            492.0  616068.833333  387473.254862  72837.0  314248.25
#
#                      50%       75%        max
# upplåtelseform
# hyra             11751.5   17256.0    28119.0
# köpa            545337.5  829735.5  1894463.0

# %%
# Kolla bostäder med pris under 10 000
df[df["pris"] < 10000]
# Out:
#       id       typ upplåtelseform  pris  avgift  rum  boyta  kvadratmeterpris  \
# 4      5  lägenhet           hyra  5147       0    2     42                 0
# 8      9       hus           hyra  3994       0    1     27                 0
# 11    12  lägenhet           hyra  4504       0    1     26                 0
# 23    24  lägenhet           hyra  2238       0    1     18                 0
# 24    25       hus           hyra  8555       0    3     69                 0
# ..   ...       ...            ...   ...     ...  ...    ...               ...
# 983  984  lägenhet           hyra  8676       0    3     57                 0
# 985  986       hus           hyra  5773       0    2     44                 0
# 990  991       hus           hyra  9758       0    3     75                 0
# 993  994  lägenhet           hyra  3792       0    1     27                 0
# 998  999  lägenhet           hyra  3172       0    1     23                 0
#
#             område       stad              adress       lat       lon  \
# 4      Linnéstaden   Göteborg       Kyrkogatan 79  57.69152  11.96112
# 8      Kungsholmen  Stockholm        Sveavägen 88  59.33732  18.03296
# 11          Hyllie      Malmö         Skolvägen 2  55.55550  12.97984
# 23     Kungsholmen  Stockholm        Skolvägen 42  59.33046  18.02808
# 24     Linnéstaden   Göteborg       Hornsgatan 70  57.69136  11.95017
# ..             ...        ...                 ...       ...       ...
# 983    Kungsholmen  Stockholm  Drottninggatan 106  59.32571  18.01995
# 985       Hisingen   Göteborg        Parkvägen 11  57.73817  11.90430
# 990  Västra Hamnen      Malmö       Hornsgatan 75  55.60580  12.98022
# 993      Södermalm  Stockholm        Kyrkogatan 3  59.30858  18.07920
# 998      Rosengård      Malmö       Bergsgatan 51  55.58942  13.03934
#
#      tillgänglig  created_at valuta boyta_enhet  pris_per_kvm
# 4           True  2026-04-08    SEK          m²         123.0
# 8           True  2026-02-22    SEK          m²         148.0
# 11         False  2025-06-30    SEK          m²         173.0
# 23          True  2025-05-10    SEK          m²         124.0
# 24          True  2026-02-10    SEK          m²         124.0
# ..           ...         ...    ...         ...           ...
# 983         True  2025-07-05    SEK          m²         152.0
# 985        False  2025-05-22    SEK          m²         131.0
# 990        False  2025-10-30    SEK          m²         130.0
# 993        False  2025-07-15    SEK          m²         140.0
# 998        False  2026-03-13    SEK          m²         138.0
#
# [201 rows x 18 columns]

# %%
df["typ"].value_counts().plot(kind="pie", autopct="%1.1f%%")
plt.title("Fördelning av bostadstyp")
plt.show()

# %%
# Visa snittpris per område
df.groupby("område")["pris"].mean().sort_values().plot(kind="barh", figsize=(10,6))
plt.title("Snittpris per område")
plt.xlabel("Pris (SEK)")
plt.show()

# %%
# Visa prisfördelning
plt.figure(figsize=(10,6))
sns.histplot(df["pris"], bins=30)
plt.title("Prisfördelning av bostäder")
plt.xlabel("Pris (SEK)")
plt.ylabel("Antal bostäder")
plt.show()

# %% [markdown]
# #### Använder SQL för att analysera data på ett strukturerat sätt, precis som man skulle göra mot en riktig databas

# %%
import duckdb 

# Använd DuckDB för att köra SQL-frågor på DataFrame
con = duckdb.connect()
con.register("right_home",df)

# %%
# Visa snittpris per område med SQL
con.execute("""
    SELECT område, 
           ROUND(AVG(pris), 0) as snittpris,
           COUNT(*) as antal
    FROM right_home
    GROUP BY område
    ORDER BY snittpris DESC
""").df()
# Out:
#            område  snittpris  antal
# 0       Östermalm   486821.0     93
# 1       Södermalm   466680.0     71
# 2     Kungsholmen   448014.0     85
# 3        Vasastan   438234.0     68
# 4         Centrum   319272.0     87
# 5        Hisingen   249736.0     85
# 6     Linnéstaden   246279.0     87
# 7         Majorna   233775.0     69
# 8         Limhamn   225722.0     77
# 9   Västra Hamnen   216130.0    105
# 10         Hyllie   212129.0     88
# 11      Rosengård   209308.0     85

# %%
# hyra mot köp 
con.execute("""
    SELECT upplåtelseform,
           COUNT(*) as antal,
           ROUND(AVG(pris), 0) as snittpris,
           MIN(pris) as lägsta,
           MAX(pris) as högsta
    FROM right_home
    GROUP BY upplåtelseform
""").df()
# Out:
#   upplåtelseform  antal  snittpris  lägsta   högsta
# 0           hyra    508    12358.0    2238    28119
# 1           köpa    492   616069.0   72837  1894463

# %%
# Tillgängliga bostäder per stad 
con.execute("""
    SELECT stad,
           COUNT(*) as antal,
           SUM(CASE WHEN tillgänglig = true THEN 1 ELSE 0 END) as tillgängliga
    FROM right_home
    GROUP BY stad
""").df()
# Out:
#         stad  antal  tillgängliga
# 0      Malmö    355         267.0
# 1   Göteborg    328         244.0
# 2  Stockholm    317         248.0
